# %%
import pandas as pd
import numpy as np

# %%
Data = pd.read_csv("Data/train.csv", nrows=10_000_000)

# %% [markdown]
#  # Computing Distance

# %%
Data["abs_latitude"]=abs(Data["pickup_latitude"]-Data["dropoff_latitude"])
Data["abs_longitude"]=abs(Data["pickup_longitude"]-Data["dropoff_longitude"])

# %%
Data["Vector"] = Data["abs_latitude"] + Data["abs_longitude"]

# %%
Data_na=Data.dropna()

# %%
Data_na
# Out:
#                                    key  fare_amount          pickup_datetime  \
# 0          2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1          2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2         2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3          2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4        2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                ...          ...                      ...
# 9999995  2012-08-12 01:18:00.000000208          5.7  2012-08-12 01:18:00 UTC
# 9999996  2013-08-07 10:28:00.000000147          5.5  2013-08-07 10:28:00 UTC
# 9999997   2013-10-29 08:29:00.00000082         14.0  2013-10-29 08:29:00 UTC
# 9999998    2012-04-07 16:41:33.0000004         10.5  2012-04-07 16:41:33 UTC
# 9999999   2010-03-30 19:27:00.00000066          8.5  2010-03-30 19:27:00 UTC
#
# ...

# %%
df = Data_na
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_36da3_row0_col0, #T_36da3_row1_col1, #T_36da3_row2_col2, #T_36da3_row3_col3, #T_36da3_row4_col4, #T_36da3_row5_col5, #T_36da3_row6_col6, #T_36da3_row7_col7, #T_36da3_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_36da3_row0_col1, #T_36da3_row5_col2, #T_36da3_row5_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_36da3_row0_col2, #T_36da3_row5_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_36da3_row0_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_36da3_row0_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_36da3_row0_col5, #T_36da3_row1_col0, #T_36da3_row6_col0, #T_36da3_row7_col0, #T_36da3_row8_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_36da3_row0_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_36da3_row0_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_36da3_row0_col8 {
# ...

# %%
Data_na['DateTime'] = pd.to_datetime(Data_na['pickup_datetime'])

# %%
Data_na['pickup_datetime']
# Out:
# 0          2009-06-15 17:26:21 UTC
# 1          2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00 UTC
# 3          2012-04-21 04:30:42 UTC
# 4          2010-03-09 07:51:00 UTC
#                     ...
# 9999995    2012-08-12 01:18:00 UTC
# 9999996    2013-08-07 10:28:00 UTC
# 9999997    2013-10-29 08:29:00 UTC
# 9999998    2012-04-07 16:41:33 UTC
# 9999999    2010-03-30 19:27:00 UTC
# Name: pickup_datetime, Length: 9999931, dtype: object
